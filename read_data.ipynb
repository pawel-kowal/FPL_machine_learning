# %%
import pandas as pd
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')

# %%
df = pd.read_csv(r"C:\Users\user\fantasy_premier_league\Fantasy-Premier-League\data\2023-24\gws\merged_gw.csv")
df_raw = df
df_history = df_raw[(df_raw.GW >= 29) & (df_raw.GW<=37)]
df = df[df.GW >= 34]

# %%
df.GW.value_counts()
# Out:
# GW
# 37    1132
# 34    1099
# 35     960
# 38     865
# 36     859
# Name: count, dtype: int64

# %%
teams = pd.read_csv(r"C:\Users\user\fantasy_premier_league\Fantasy-Premier-League\data\2023-24\teams.csv")
teams = teams[['id', 'short_name']]
teams.head()
# Out:
#    id short_name
# 0   1        ARS
# 1   2        AVL
# 2   3        BOU
# 3   4        BRE
# 4   5        BHA

# %%
for i in range(1, 6):
    for j in range(1,6):
        df_loop = df[df.GW==j+33]
        df_loop = df_loop.merge(
            df_history[df_history['GW'] == df_loop['GW'].iloc[0] - i],
            on='name',
            suffixes=('', f'_{-i}')
        )
        if j == 1 and i == 1: 
            df_finish = df_loop
        else: 
            df_finish = pd.concat([df_finish, df_loop], ignore_index=True)
df_finish.tail(20)
# Out:
#                          name position            team   xP  assists  bonus  \
# 25053            Joseph Anang       GK        West Ham -1.0        0      0
# 25054          George Baldock      DEF   Sheffield Utd  0.0        0      0
# 25055           Jeff Hendrick      MID       Newcastle  0.0        0      0
# 25056          Mark Gillespie       GK       Newcastle  0.0        0      0
# 25057          Ronnie Stutter      FWD         Chelsea  0.0        0      0
# 25058    Nélson Cabral Semedo      DEF          Wolves -0.7        0      0
# 25059          Wesley Okoduwa      DEF          Wolves -0.5        0      0
# 25060             Kevin Mbabu      DEF          Fulham  0.0        0      0
# 25061          Tyrell Malacia      DEF         Man Utd  0.0        0      0
# 25062      Hákon Valdimarsson       GK       Brentford  0.0        0      0
# 25063          Đorđe Petrović       GK         Chelsea  3.8        0      0
# ...

# %% [markdown]
# ### TODO
# - ogarnąć podwójne kolejki (jeszcze nie wiem jak)
# - ogarnąć concata i joina
